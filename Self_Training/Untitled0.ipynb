# %%
pip install git+https://github.com/philferriere/cocoapi.git#subdirectory=PythonAPI
# Out:
# ...
#   Cloning https://github.com/philferriere/cocoapi.git to /tmp/pip-req-build-qeko5670
#   Running command git clone -q https://github.com/philferriere/cocoapi.git /tmp/pip-req-build-qeko5670
# ...
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp36-cp36m-linux_x86_64.whl size=267188 sha256=2653768b783e23b369f228f620a74d1096f0d753ee90d201a14da5a71568c515
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tqc75qff/wheels/69/2b/12/2fa959e49f73d26cff202c2f4e5079096c9c57c8a8509fd75c
# Successfully built pycocotools
# ...
#   Found existing installation: pycocotools 2.0.1
#     Uninstalling pycocotools-2.0.1:
#       Successfully uninstalled pycocotools-2.0.1
# ...

# %%
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'anaconda'

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
